# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the fixed Heart Disease dataset
#url = "https://github.com/asthasharma98/Heart-Disease-Prediction-Deployment/blob/master/heart_cleveland_upload.csv"
heart = pd.read_csv(r"C:\Users\Rammah\OneDrive\Desktop\heart_cleveland_upload.csv")

# Show first 5 rows
print("🔹 First 5 rows:")
print(heart.head())

# 1. Age distribution
print("\n📊 Age distribution (binned):")
print(heart['age'].value_counts(bins=5).sort_index())

# 2. Heart disease count by gender
print("\n❤️ Heart disease count by gender:")
print(heart.groupby('sex')['condition'].value_counts().unstack())

# 3. Correlation with target
print("\n📌 Correlation with 'HeartDisease':")
print(heart.corr(numeric_only=True)['condition'].sort_values(ascending=False))

# 4. Cholesterol and MaxHR summary
print("\n🧪 Cholesterol Summary:")
print(heart['chol'].describe())

print("\n🧪 MaxHR Summary:")
print(heart['trestbps'].describe())
# Out:
# 🔹 First 5 rows:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0
#
# 📊 Age distribution (binned):
# (28.951, 38.6]     10
# (38.6, 48.2]       70
# (48.2, 57.8]       94
# (57.8, 67.4]      106
# (67.4, 77.0]       17
# Name: count, dtype: int64
#
# ❤️ Heart disease count by gender:
# condition   0    1
# sex
# 0          71   25
# 1          89  112
#
# 📌 Correlation with 'HeartDisease':
# ...

# %%
# Show first 5 rows
print("🔹 First 5 rows:")
print(heart.head())
# Out:
# 🔹 First 5 rows:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0

# %%
# 1. Age distribution
print("\n📊 Age distribution (binned):")
print(heart['age'].value_counts(bins=5).sort_index())
# Out:
# 📊 Age distribution (binned):
# (28.951, 38.6]     10
# (38.6, 48.2]       70
# (48.2, 57.8]       94
# (57.8, 67.4]      106
# (67.4, 77.0]       17
# Name: count, dtype: int64

# %%
# Age distribution
heart['age'].hist(bins=10)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
# 2. Heart disease count by gender
print("\n❤️ Heart disease count by gender:")
print(heart.groupby('sex')['condition'].value_counts().unstack())
# Out:
# ❤️ Heart disease count by gender:
# condition   0    1
# sex
# 0          71   25
# 1          89  112

# %%
heart['sex'] = heart['sex'].map({0: 'Male', 1: 'Female'})

# %%
sns.countplot(data=heart, x='sex', hue='condition')
plt.title("Heart disease count  by Gender")
plt.show()

# %%
# 3. Correlation with target
print("\n📌 Correlation with 'HeartDisease':")
print(heart.corr(numeric_only=True)['condition'].sort_values(ascending=False))
# Out:
# 📌 Correlation with 'HeartDisease':
# condition    1.000000
# thal         0.520516
# ca           0.463189
# oldpeak      0.424052
# exang        0.421355
# cp           0.408945
# slope        0.333049
# sex          0.278467
# age          0.227075
# restecg      0.166343
# trestbps     0.153490
# chol         0.080285
# fbs          0.003167
# thalach     -0.423817
# Name: condition, dtype: float64

# %%
# Correlation heatmap
sns.heatmap(heart.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
# 4. Cholesterol and MaxHR summary
print("\n🧪 Cholesterol Summary:")
print(heart['chol'].describe())
# Out:
# 🧪 Cholesterol Summary:
# count    297.000000
# mean     247.350168
# std       51.997583
# min      126.000000
# 25%      211.000000
# 50%      243.000000
# 75%      276.000000
# max      564.000000
# Name: chol, dtype: float64

# %%
print("\n🧪 MaxHR Summary:")
print(heart['trestbps'].describe())
# Out:
# 🧪 MaxHR Summary:
# count    297.000000
# mean     131.693603
# std       17.762806
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
# Boxplot
sns.boxplot(data=heart['trestbps'])
plt.title("Boxplot of Features by Species")
plt.xticks(rotation=45)
plt.show()

# %%
# Boxplot
sns.boxplot(data=heart[['chol','thalach']])
plt.title("Boxplot of Features by Species")
plt.xticks(rotation=45)
plt.show()
